# %% [markdown]
# # VS Code Jupyter 測試 Notebook
#
# 請依序執行下面的程式區塊，確認 VS Code 可以正常執行 `.ipynb`。
#
# - 如果看到輸出結果，表示環境可用。
# - 若看不到輸出或出現錯誤，請確認 Python 直譯器與 Jupyter 外掛已設定完成。

# %%
# Hello World
message = "哈囉，VS Code Notebook！"
print(message)
# Out:
# 哈囉，VS Code Notebook！

# %%
# 簡單運算
a = 10
b = 20
print(f"{a} + {b} = {a + b}")
# Out:
# 10 + 20 = 30

# %%
# 檢查直譯器路徑
import sys
print(sys.executable)
# Out:
# c:\Users\User\anaconda3\python.exe
